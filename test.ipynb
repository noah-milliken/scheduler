# %%
import streamlit as st
from streamlit_gsheets import GSheetsConnection


def get_sheet():
    conn = st.connection("gsheets", type=GSheetsConnection)
    data = conn.read(worksheet="Sheet1")
    time_cols = ["Name", "Location", "Start-Time-Str", "End-Time-Str"]
    data = data[time_cols].dropna(subset=time_cols)
    data_list = []
    for index, row in data.iterrows():

        entry = {
            "title": row["Name"],
            "start": row["Start-Time-Str"],
            "end": row["End-Time-Str"],
            "resourceId": row["Location"],
        }
        data_list.append(entry)
    return data_list
# Out:
# 2024-04-29 20:07:20.844 No runtime found, using MemoryCacheStorageManager
# [{'title': 'Veronica', 'start': '2024-05-01T08:00:00', 'end': '2024-05-01T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-02T08:00:00', 'end': '2024-05-02T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-03T08:00:00', 'end': '2024-05-03T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-06T08:00:00', 'end': '2024-05-06T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-07T08:00:00', 'end': '2024-05-07T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-08T08:00:00', 'end': '2024-05-08T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-09T08:00:00', 'end': '2024-05-09T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-13T08:00:00', 'end': '2024-05-13T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-14T08:00:00', 'end': '2024-05-14T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-15T08:00:00', 'end': '2024-05-15T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-16T08:00:00', 'end': '2024-05-16T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-20T08:00:00', 'end': '2024-05-20T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-21T08:00:00', 'end': '2024-05-21T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-22T08:00:00', 'end': '2024-05-22T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-23T08:00:00', 'end': '2024-05-23T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-27T08:00:00', 'end': '2024-05-27T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-28T08:00:00', 'end': '2024-05-28T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-29T08:00:00', 'end': '2024-05-29T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Veronica', 'start': '2024-05-30T08:00:00', 'end': '2024-05-30T16:00:00', 'resourceId': 'rec_center'}, {'title': 'Noah', 'start': '2024-05-06T15:00:00', 'end': '2024-05-06T18:30:00', 'resourceId': 'stryker'}, {'title': 'Noah', 'start': '2024-05-08T14:00:00', 'end': '2024-05-08T18:30:00', 'resourceId': 'stryker'}, {'title': 'Noah', 'start': '2024-05-14T17:30:00', 'end': '2024-05-14T21:00:00', 'resourceId': 'stryker'}, {'title': 'Noah', 'start': '2024-05-20T17:00:00', 'end': '2024-05-20T20:00:00', 'resourceId': 'stryker'}, {'title': 'Noah', 'start': '2024-05-28T17:30:00', 'end': '2024-05-28T21:00:00', 'resourceId': 'stryker'}, {'title': 'Noah', 'start': '2024-05-01T16:00:00', 'end': '2024-05-01T21:00:00', 'resourceId': 'rec_center'}, {'title': nan, 'start': "#VALUE! (DATEVALUE parameter '' cannot be parsed to date/time.)", 'end': "#VALUE! (DATEVALUE parameter '' cannot be parsed to date/time.)", 'resourceId': nan}, {'title': nan, 'start': "#VALUE! (DATEVALUE parameter '' cannot be parsed to date/time.)", 'end': "#VALUE! (DATEVALUE parameter '' cannot be parsed to date/time.)", 'resourceId': nan}, {'title': nan, 'start': "#VALUE! (DATEVALUE parameter '' cannot be parsed to date/time.)", 'end': "#VALUE! (DATEVALUE parameter '' cannot be parsed to date/time.)", 'resourceId': nan}, {'title': nan, 'start': "#VALUE! (DATEVALUE parameter '' cannot be parsed to date/time.)", 'end': "#VALUE! (DATEVALUE parameter '' cannot be parsed to date/time.)", 'resourceId': nan}, {'title': nan, 'start': "#VALUE! (DATEVALUE parameter '' cannot be parsed to date/time.)", 'end': "#VALUE! (DATEVALUE parameter '' cannot be parsed to date/time.)", 'resourceId': nan}, {'title': nan, 'start': "#VALUE! (DATEVALUE parameter '' cannot be parsed to date/time.)", 'end': "#VALUE! (DATEVALUE parameter '' cannot be parsed to date/time.)", 'resourceId': nan}, {'title': nan, 'start': "#VALUE! (DATEVALUE parameter '' cannot be parsed to date/time.)", 'end': "#VAL ...

# %%
print(data[['Name', 'Location','Start-Time-Str',
       'End-Time-Str']])
# Out:
#          Name    Location       Start-Time-Str         End-Time-Str
# 0    Veronica  rec_center  2024-05-01T08:00:00  2024-05-01T16:00:00
# 1    Veronica  rec_center  2024-05-02T08:00:00  2024-05-02T16:00:00
# 2    Veronica  rec_center  2024-05-03T08:00:00  2024-05-03T16:00:00
# 3    Veronica  rec_center  2024-05-06T08:00:00  2024-05-06T16:00:00
# 4    Veronica  rec_center  2024-05-07T08:00:00  2024-05-07T16:00:00
# ..        ...         ...                  ...                  ...
# 994       NaN         NaN                  NaN                  NaN
# 995       NaN         NaN                  NaN                  NaN
# 996       NaN         NaN                  NaN                  NaN
# 997       NaN         NaN                  NaN                  NaN
# 998       NaN         NaN                  NaN                  NaN
#
# [999 rows x 4 columns]
